# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import sklearn.cluster as kMeans
import numpy as np
import statsmodels.api as smf
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
#metricas de avaliação
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("/content/dengue_35-20 caucaia.csv", sep=",")
df
# Out:
#     data_iniSE      SE  casos_est  casos_est_min  casos_est_max  casos  \
# 0   2024-05-05  202419      146.5              8           1201      0
# 1   2024-04-28  202418      117.0              9            973      0
# 2   2024-04-21  202417      109.0              8            828      0
# 3   2024-04-14  202416      109.0             33            656     28
# 4   2024-04-07  202415       63.0             11            474      9
# 5   2024-03-31  202414       70.0             38            292     37
# 6   2024-03-24  202413       82.0             70            211     70
# 7   2024-03-17  202412       72.0             68            139     68
# 8   2024-03-10  202411       53.0             53             63     53
# 9   2024-03-03  202410       39.0             39             45     39
# 10  2024-02-25  202409       68.0             68             68     68
# 11  2024-02-18  202408       45.0             45             45     45
# 12  2024-02-11  202407       27.0             27             27     27
# 13  2024-02-04  202406       17.0             17             17     17
# 14  2024-01-28  202405       12.0             12             12     12
# 15  2024-01-21  202404       13.0             13             13     13
# 16  2024-01-14  202403       12.0             12             12     12
# 17  2024-01-07  202402        9.0              9              9      9
# 18  2023-12-31  202401        7.0              7              7      7
# 19  2023-12-24  202352        1.0              1              1      1
# 20  2023-12-17  202351        0.0              0              0      0
# 21  2023-12-10  202350        0.0              0              0      0
# 22  2023-12-03  202349        0.0              0              0      0
# 23  2023-11-26  202348        0.0              0              0      0
# 24  2023-11-19  202347        4.0              4              4      4
# 25  2023-11-12  202346        5.0              5              5      5
# 26  2023-11-05  202345        1.0              1              1      1
# 27  2023-10-29  202344        2.0              2              2      2
# 28  2023-10-22  202343        5.0              5              5      5
# 29  2023-10-15  202342       10.0             10             10     10
# 30  2023-10-08  202341        0.0              0              0      0
# 31  2023-10-01  202340       11.0             11             11     11
# 32  2023-09-24  202339        3.0              3              3      3
# 33  2023-09-17  202338        5.0              5              5      5
# 34  2023-09-10  202337        4.0              4              4      4
# 35  2023-09-03  202336        2.0              2              2      2
# 36  2023-08-27  202335        3.0              3              3      3
#
#        p_rt1  p_inc100k  Localidade_id  nivel  ...    umidmed    umidmin  \
# 0   0.989274  39.338047              0      1  ...  80.711254  80.237182
# 1   0.929728  31.416733              0      1  ...  87.276541  86.167180
# 2   0.985769  29.268581              0      3  ...  85.237595  84.198522
# 3   0.996336  29.268581              0      1  ...  86.518861  84.641308
# 4   0.183154  16.916702              0      1  ...  87.234853  85.411612
# 5   0.581897  18.796337              0      1  ...  84.341718  83.691123
# 6   0.986026  22.018566              0      3  ...  88.569791  86.154237
# 7   0.969766  19.333374              0      1  ...  84.939883  83.427196
# 8   0.544894  14.231512              0      1  ...  86.565718  84.363271
# 9   0.289895  10.472244              0      1  ...  81.933883  81.365461
# 10  0.999949  18.259298              0      3  ...  86.717874  84.979635
# 11  0.999436  12.083359              0      3  ...  85.085193  84.062718
# 12  0.978994   7.250015              0      1  ...  84.707208  83.928550
# 13  0.804170   4.564825              0      1  ...  78.714073  78.369635
# 14  0.572155   3.222229              0      1  ...  75.526337  74.565351
# 15  0.812010   3.490748              0      1  ...  77.418077  77.090042
# 16  0.933749   3.222229              0      1  ...  78.470939  77.534893
# 17  0.978538   2.416672              0      1  ...  77.653739  76.987920
# 18  0.996830   1.879634              0      1  ...  80.986075  79.661418
# 19  0.951062   0.268519              0      1  ...  79.934828  76.765887
# 20  0.000000   0.000000              0      1  ...  79.063176  76.548805
# 21  0.000000   0.000000              0      1  ...  76.038369  67.626502
# 22  0.000000   0.000000              0      1  ...  73.772622  55.443224
# 23  0.000000   0.000000              0      1  ...        NaN        NaN
# 24  0.716633   1.074076              0      1  ...        NaN        NaN
# 25  0.765435   1.342596              0      1  ...  79.022647  78.113207
# 26  0.031217   0.268519              0      1  ...  73.516632  69.865381
# 27  0.065584   0.537038              0      1  ...  77.109717  71.139632
# 28  0.431762   1.342596              0      1  ...  77.925172  73.896237
# 29  0.853105   2.685191              0      1  ...  76.632077  74.158368
# 30  0.000000   0.000000              0      1  ...  78.153370  74.662743
# 31  0.960705   2.953710              0      1  ...  76.299059  72.136944
# 32  0.396003   0.805557              0      1  ...  78.747137  72.475238
# 33  0.763369   1.342596              0      1  ...  79.001807  76.002810
# 34  0.549489   1.074076              0      1  ...  76.459191  66.929103
# 35  0.078355   0.537038              0      1  ...        NaN        NaN
# 36  0.082727   0.805557              0      1  ...        NaN        NaN
#
#       tempmed    tempmax  casprov  casprov_est  casprov_est_min  \
# 0   28.488889  28.555556      NaN          NaN              NaN
# 1   27.304545  27.454545      NaN          NaN              NaN
# 2   27.113636  27.181818      NaN          NaN              NaN
# 3   27.684211  27.894737      NaN          NaN              NaN
# 4   27.736842  28.000000      NaN          NaN              NaN
# 5   28.125000  28.200000      NaN          NaN              NaN
# 6   27.361111  27.611111      NaN          NaN              NaN
# 7   28.175000  28.250000      NaN          NaN              NaN
# 8   27.900000  28.000000      NaN          NaN              NaN
# 9   28.156863  28.176471      NaN          NaN              NaN
# 10  27.075000  27.500000      NaN          NaN              NaN
# 11  27.681818  27.818182      NaN          NaN              NaN
# 12  27.841270  28.000000      NaN          NaN              NaN
# 13  29.000000  29.000000      NaN          NaN              NaN
# 14  28.928571  29.000000      NaN          NaN              NaN
# 15  28.714286  28.714286      NaN          NaN              NaN
# 16  28.000000  28.000000      NaN          NaN              NaN
# 17  28.214286  28.285714      NaN          NaN              NaN
# 18  27.950000  28.050000      NaN          NaN              NaN
# 19  28.101449  28.695652      NaN          NaN              NaN
# 20  27.978261  28.391304      NaN          NaN              NaN
# 21  27.919355  29.516129      NaN          NaN              NaN
# 22  28.402777  31.500000      NaN          NaN              NaN
# 23        NaN        NaN      NaN          NaN              NaN
# 24        NaN        NaN      NaN          NaN              NaN
# 25  27.230769  27.307692      NaN          NaN              NaN
# 26  27.800000  28.450000      NaN          NaN              NaN
# 27  27.507246  28.173913      NaN          NaN              NaN
# 28  27.015873  27.952381      NaN          NaN              NaN
# 29  27.119318  27.545455      NaN          NaN              NaN
# 30  27.193750  27.600000      NaN          NaN              NaN
# 31  27.125000  27.714286      NaN          NaN              NaN
# 32  26.916667  27.944444      NaN          NaN              NaN
# 33  27.142045  27.681818      NaN          NaN              NaN
# 34  27.333333  29.000000      NaN          NaN              NaN
# 35        NaN        NaN      NaN          NaN              NaN
# 36        NaN        NaN      NaN          NaN              NaN
#
#     casprov_est_max  casconf  notif_accum_year
# 0               NaN      NaN               570
# 1               NaN      NaN               570
# 2               NaN      NaN               570
# 3               NaN      NaN               570
# 4               NaN      NaN               570
# 5               NaN      NaN               570
# 6               NaN      NaN               570
# 7               NaN      NaN               570
# 8               NaN      NaN               570
# 9               NaN      NaN               570
# 10              NaN      NaN               570
# 11              NaN      NaN               570
# 12              NaN      NaN               570
# 13              NaN      NaN               570
# 14              NaN      NaN               570
# 15              NaN      NaN               570
# 16              NaN      NaN               570
# 17              NaN      NaN               570
# 18              NaN      NaN               570
# 19              NaN      NaN               570
# 20              NaN      NaN               570
# 21              NaN      NaN               570
# 22              NaN      NaN               570
# 23              NaN      NaN               570
# 24              NaN      NaN               570
# 25              NaN      NaN               570
# 26              NaN      NaN               570
# 27              NaN      NaN               570
# 28              NaN      NaN               570
# 29              NaN      NaN               570
# 30              NaN      NaN               570
# 31              NaN      NaN               570
# 32              NaN      NaN               570
# 33              NaN      NaN               570
# 34              NaN      NaN               570
# 35              NaN      NaN               570
# 36              NaN      NaN               570
#
# [37 rows x 30 columns]

# %%
df["data_iniSE"] = pd.to_datetime(df["data_iniSE"])
mes = df["data_iniSE"].dt.month
dia = df["data_iniSE"].dt.day
#ano = df["data_iniSE"].dt.year
casos = df["casos"]
tempmed = df["tempmed"]
umidmed = df["umidmed"]

# %%
df1 = pd.DataFrame({'Dia': dia,'Mês':mes, 'Casos': casos, 'TemperaturaM':tempmed, 'UmidadeM':umidmed})

# %%
df1
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      0     27.304545  87.276541
# 2    21    4      0     27.113636  85.237595
# 3    14    4     28     27.684211  86.518861
# 4     7    4      9     27.736842  87.234853
# 5    31    3     37     28.125000  84.341718
# 6    24    3     70     27.361111  88.569791
# 7    17    3     68     28.175000  84.939883
# 8    10    3     53     27.900000  86.565718
# 9     3    3     39     28.156863  81.933883
# 10   25    2     68     27.075000  86.717874
# 11   18    2     45     27.681818  85.085193
# 12   11    2     27     27.841270  84.707208
# 13    4    2     17     29.000000  78.714073
# 14   28    1     12     28.928571  75.526337
# 15   21    1     13     28.714286  77.418077
# 16   14    1     12     28.000000  78.470939
# 17    7    1      9     28.214286  77.653739
# 18   31   12      7     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      0     27.978261  79.063176
# 21   10   12      0     27.919355  76.038369
# 22    3   12      0     28.402777  73.772622
# 23   26   11      0           NaN        NaN
# 24   19   11      4           NaN        NaN
# 25   12   11      5     27.230769  79.022647
# 26    5   11      1     27.800000  73.516632
# 27   29   10      2     27.507246  77.109717
# 28   22   10      5     27.015873  77.925172
# 29   15   10     10     27.119318  76.632077
# 30    8   10      0     27.193750  78.153370
# 31    1   10     11     27.125000  76.299059
# 32   24    9      3     26.916667  78.747137
# 33   17    9      5     27.142045  79.001807
# 34   10    9      4     27.333333  76.459191
# 35    3    9      2           NaN        NaN
# 36   27    8      3           NaN        NaN

# %%
sns.countplot(x="Casos", data=df1);

# %%
columns_to_remove = ["SE","id","casos_est",
                     "casos_est_min","casos_est_max",
                     "p_rt1","p_inc100k",
                     "Localidade_id","nivel",
                     "casprov","casprov_est","casprov_est_min",
                     "casprov_est_max","casconf","tweet","Rt","pop","receptivo",
                     "transmissao","nivel_inc","notif_accum_year","versao_modelo" ]
df = df.drop(columns_to_remove, axis=1)
df.sample(4)
# Out:
#    data_iniSE  casos    tempmin    umidmax    umidmed    umidmin    tempmed  \
# 35 2023-09-03      2        NaN  82.492783        NaN        NaN        NaN
# 17 2024-01-07      9  28.142857  78.319558  77.653739  76.987920  28.214286
# 8  2024-03-10     53  27.800000  88.768165  86.565718  84.363271  27.900000
# 10 2024-02-25     68  26.650000  88.472379  86.717874  84.979635  27.075000
#
#       tempmax
# 35        NaN
# 17  28.285714
# 8   28.000000
# 10  27.500000

# %%
df.isnull().sum()
# Out:
# data_iniSE    0
# casos         0
# tempmin       4
# umidmax       0
# umidmed       4
# umidmin       4
# tempmed       4
# tempmax       4
# dtype: int64

# %%
df1_treino = df1.dropna(subset=["TemperaturaM","UmidadeM"])

# %%
X = df1_treino.drop('Casos',axis=1)
y= df1_treino['Casos']

# %%
X
# Out:
#     Dia  Mês  TemperaturaM   UmidadeM
# 0     5    5     28.488889  80.711254
# 1    28    4     27.304545  87.276541
# 2    21    4     27.113636  85.237595
# 3    14    4     27.684211  86.518861
# 4     7    4     27.736842  87.234853
# 5    31    3     28.125000  84.341718
# 6    24    3     27.361111  88.569791
# 7    17    3     28.175000  84.939883
# 8    10    3     27.900000  86.565718
# 9     3    3     28.156863  81.933883
# 10   25    2     27.075000  86.717874
# 11   18    2     27.681818  85.085193
# 12   11    2     27.841270  84.707208
# 13    4    2     29.000000  78.714073
# 14   28    1     28.928571  75.526337
# 15   21    1     28.714286  77.418077
# 16   14    1     28.000000  78.470939
# 17    7    1     28.214286  77.653739
# 18   31   12     27.950000  80.986075
# 19   24   12     28.101449  79.934828
# 20   17   12     27.978261  79.063176
# 21   10   12     27.919355  76.038369
# 22    3   12     28.402777  73.772622
# 25   12   11     27.230769  79.022647
# 26    5   11     27.800000  73.516632
# 27   29   10     27.507246  77.109717
# 28   22   10     27.015873  77.925172
# 29   15   10     27.119318  76.632077
# 30    8   10     27.193750  78.153370
# 31    1   10     27.125000  76.299059
# 32   24    9     26.916667  78.747137
# 33   17    9     27.142045  79.001807
# 34   10    9     27.333333  76.459191

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.3,random_state= 42)

# %%
sca = preprocessing.StandardScaler()

# %%
cols = X.columns
cols
# Out:
# Index(['Dia', 'Mês', 'TemperaturaM', 'UmidadeM'], dtype='object')

# %%
df["data_iniSE"].dtype
#float_cols = X_train
# Out:
# dtype('<M8[ns]')

# %%
float_cols = X_train

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
df.data_iniSE = df['data_iniSE']

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
X_train
df1.drop([12,16,23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      0     27.304545  87.276541
# 2    21    4      0     27.113636  85.237595
# 3    14    4     28     27.684211  86.518861
# 4     7    4      9     27.736842  87.234853
# 5    31    3     37     28.125000  84.341718
# 6    24    3     70     27.361111  88.569791
# 7    17    3     68     28.175000  84.939883
# 8    10    3     53     27.900000  86.565718
# 9     3    3     39     28.156863  81.933883
# 10   25    2     68     27.075000  86.717874
# 11   18    2     45     27.681818  85.085193
# 13    4    2     17     29.000000  78.714073
# 14   28    1     12     28.928571  75.526337
# 15   21    1     13     28.714286  77.418077
# 17    7    1      9     28.214286  77.653739
# 18   31   12      7     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      0     27.978261  79.063176
# 21   10   12      0     27.919355  76.038369
# 22    3   12      0     28.402777  73.772622
# 25   12   11      5     27.230769  79.022647
# 26    5   11      1     27.800000  73.516632
# 27   29   10      2     27.507246  77.109717
# 28   22   10      5     27.015873  77.925172
# 29   15   10     10     27.119318  76.632077
# 30    8   10      0     27.193750  78.153370
# 31    1   10     11     27.125000  76.299059
# 32   24    9      3     26.916667  78.747137
# 33   17    9      5     27.142045  79.001807
# 34   10    9      4     27.333333  76.459191

# %%
y_train
df1.drop([23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      0     27.304545  87.276541
# 2    21    4      0     27.113636  85.237595
# 3    14    4     28     27.684211  86.518861
# 4     7    4      9     27.736842  87.234853
# 5    31    3     37     28.125000  84.341718
# 6    24    3     70     27.361111  88.569791
# 7    17    3     68     28.175000  84.939883
# 8    10    3     53     27.900000  86.565718
# 9     3    3     39     28.156863  81.933883
# 10   25    2     68     27.075000  86.717874
# 11   18    2     45     27.681818  85.085193
# 12   11    2     27     27.841270  84.707208
# 13    4    2     17     29.000000  78.714073
# 14   28    1     12     28.928571  75.526337
# 15   21    1     13     28.714286  77.418077
# 16   14    1     12     28.000000  78.470939
# 17    7    1      9     28.214286  77.653739
# 18   31   12      7     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      0     27.978261  79.063176
# 21   10   12      0     27.919355  76.038369
# 22    3   12      0     28.402777  73.772622
# 25   12   11      5     27.230769  79.022647
# 26    5   11      1     27.800000  73.516632
# 27   29   10      2     27.507246  77.109717
# 28   22   10      5     27.015873  77.925172
# 29   15   10     10     27.119318  76.632077
# 30    8   10      0     27.193750  78.153370
# 31    1   10     11     27.125000  76.299059
# 32   24    9      3     26.916667  78.747137
# 33   17    9      5     27.142045  79.001807
# 34   10    9      4     27.333333  76.459191

# %%
df
df1.drop([12,16,23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      0     27.304545  87.276541
# 2    21    4      0     27.113636  85.237595
# 3    14    4     28     27.684211  86.518861
# 4     7    4      9     27.736842  87.234853
# 5    31    3     37     28.125000  84.341718
# 6    24    3     70     27.361111  88.569791
# 7    17    3     68     28.175000  84.939883
# 8    10    3     53     27.900000  86.565718
# 9     3    3     39     28.156863  81.933883
# 10   25    2     68     27.075000  86.717874
# 11   18    2     45     27.681818  85.085193
# 13    4    2     17     29.000000  78.714073
# 14   28    1     12     28.928571  75.526337
# 15   21    1     13     28.714286  77.418077
# 17    7    1      9     28.214286  77.653739
# 18   31   12      7     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      0     27.978261  79.063176
# 21   10   12      0     27.919355  76.038369
# 22    3   12      0     28.402777  73.772622
# 25   12   11      5     27.230769  79.022647
# 26    5   11      1     27.800000  73.516632
# 27   29   10      2     27.507246  77.109717
# 28   22   10      5     27.015873  77.925172
# 29   15   10     10     27.119318  76.632077
# 30    8   10      0     27.193750  78.153370
# 31    1   10     11     27.125000  76.299059
# 32   24    9      3     26.916667  78.747137
# 33   17    9      5     27.142045  79.001807
# 34   10    9      4     27.333333  76.459191

# %%
X_train = sca.fit_transform(X_train)
X_train = pd.DataFrame(X_train,columns=cols)
X_test = sca.transform(X_test)
X_test = pd.DataFrame(X_test,columns=cols)

# %%
knn_model = KNeighborsRegressor(n_neighbors=3)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
X_train
# Out:
#          Dia       Mês  TemperaturaM  UmidadeM
# 0  -1.049616 -0.613151      0.093143  1.370976
# 1  -0.298557 -1.355387      0.561182 -0.496159
# 2   1.525441 -0.860563      0.783501  0.754599
# 3  -1.371498 -1.107975      2.339732 -0.444360
# 4   0.130619 -1.107975     -0.004720  0.912995
# 5  -1.264204  1.118732      0.205472 -1.551665
# 6   1.203559 -0.613151     -0.675718  1.379858
# 7   0.452501 -0.613151     -1.015260  0.945464
# 8  -1.693380  0.871320     -0.995049 -0.958874
# 9  -0.298557 -0.613151     -0.000465  1.218435
# 10 -0.191263  0.871320     -1.005154 -0.887925
# 11 -0.513145  1.118732     -0.806933 -0.378619
# 12  0.774383  0.623908     -1.365580 -0.437315
# 13 -1.478792  1.366144      1.277542 -1.497126
# 14  1.525441  1.366144      0.472255  0.039686
# 15  1.310853  0.871320     -0.315205 -0.786165
# 16  0.774383 -0.860563     -0.575114  1.655382
# 17  0.023325  1.366144      0.522518 -0.369984
# 18 -0.727734  0.623908     -0.624518 -0.924758
# 19  0.023325 -0.860563      0.872429  0.882037
# 20  0.881677 -1.107975     -1.083977  1.260835
# 21  1.203559 -1.355387      2.212693 -1.123501
# 22 -0.942322  0.871320     -0.872774 -0.563817

# %%
y_pred = knn_model.predict(X_test)
y_pred
# Out:
# array([ 6.        , 13.66666667,  5.        , 32.33333333, 35.        ,
#        29.66666667,  3.        ,  0.33333333, 27.33333333, 32.33333333])

# %%
y_train
# Out:
# 4      9
# 16    12
# 5     37
# 13    17
# 11    45
# 26     1
# 1      0
# 2      0
# 31    11
# 3     28
# 29    10
# 25     5
# 32     3
# 22     0
# 18     7
# 27     2
# 6     70
# 20     0
# 34     4
# 7     68
# 10    68
# 14    12
# 30     0
# Name: Casos, dtype: int64

# %%
#Dados nulos
df1.isnull().sum()
# Out:
# Dia             0
# Mês             0
# Casos           0
# TemperaturaM    4
# UmidadeM        4
# dtype: int64

# %%
sns.countplot(x="Casos", data=df1);

# %%
fig = px.scatter(df1, x="Casos",
                 y="Mês",
                 title= "Numeros de Casos")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a2b06ee0-3dc4-4f65-a713-7784c0da9df0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2b06ee0-3dc4-4f65-a713-7784c0da9df0")) {                    Plotly.newPlot(                        "a2b06ee0-3dc4-4f65-a713-7784c0da9df0",                        [{"hovertemplate":"Casos=%{x}\u003cbr\u003eM\u00eas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0,0,0,28,9,37,70,68,53,39,68,45,27,17,12,13,12,9,7,1,0,0,0,0,4,5,1,2,5,10,0,11,3,5,4,2,3],"xaxis":"x","y":[5,4,4,4,4,3,3,3,3,3,2,2,2,2,1,1,1,1,12,12,12,12,12,11,11,11,11,10,10,10,10,10,9,9,9,9,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}], ...

# %%
fig = px.scatter(x=y_test, y=y_pred, title="Casos por Mês", trendline="ols", labels= {"X":"Casos","y":"Mês"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a383f707-80c4-4f79-a48e-be5f4955b52e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a383f707-80c4-4f79-a48e-be5f4955b52e")) {                    Plotly.newPlot(                        "a383f707-80c4-4f79-a48e-be5f4955b52e",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eM\u00eas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[5,13,5,9,53,39,1,0,27,0],"xaxis":"x","y":[6.0,13.666666666666666,5.0,32.333333333333336,35.0,29.666666666666668,3.0,0.3333333333333333,27.333333333333332,32.333333333333336],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ey = 0.481943 * x + 11.1411\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.395753\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003eM\u00eas=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0,0,1,5,5,9,13,27,39,53],"xaxis":"x","y":[11.141133263378803,11.141133263378803,11.623076250437215,13.550848198670863,13.550848198670863,15.47862014690451,17.406392095138155,24.153593913955923,29.93690975865686,36.684111577474624],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12,8))

# %%
sns.countplot(x="Casos", data=df1)
plt.title("Nível de casos")
# Out:
# Text(0.5, 1.0, 'Nível de casos')

# %%
decision_tree = DecisionTreeClassifier()

# %%
df1
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      0     27.304545  87.276541
# 2    21    4      0     27.113636  85.237595
# 3    14    4     28     27.684211  86.518861
# 4     7    4      9     27.736842  87.234853
# 5    31    3     37     28.125000  84.341718
# 6    24    3     70     27.361111  88.569791
# 7    17    3     68     28.175000  84.939883
# 8    10    3     53     27.900000  86.565718
# 9     3    3     39     28.156863  81.933883
# 10   25    2     68     27.075000  86.717874
# 11   18    2     45     27.681818  85.085193
# 12   11    2     27     27.841270  84.707208
# 13    4    2     17     29.000000  78.714073
# 14   28    1     12     28.928571  75.526337
# 15   21    1     13     28.714286  77.418077
# 16   14    1     12     28.000000  78.470939
# 17    7    1      9     28.214286  77.653739
# 18   31   12      7     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      0     27.978261  79.063176
# 21   10   12      0     27.919355  76.038369
# 22    3   12      0     28.402777  73.772622
# 23   26   11      0           NaN        NaN
# 24   19   11      4           NaN        NaN
# 25   12   11      5     27.230769  79.022647
# 26    5   11      1     27.800000  73.516632
# 27   29   10      2     27.507246  77.109717
# 28   22   10      5     27.015873  77.925172
# 29   15   10     10     27.119318  76.632077
# 30    8   10      0     27.193750  78.153370
# 31    1   10     11     27.125000  76.299059
# 32   24    9      3     26.916667  78.747137
# 33   17    9      5     27.142045  79.001807
# 34   10    9      4     27.333333  76.459191
# 35    3    9      2           NaN        NaN
# 36   27    8      3           NaN        NaN

# %%
X_test
# Out:
#         Dia       Mês  TemperaturaM  UmidadeM
# 0  0.023325  0.623908     -0.964733 -0.383059
# 1  0.452501 -1.355387      1.831575 -0.720469
# 2  0.559795  0.871320     -1.189137 -0.612434
# 3 -1.049616 -1.355387      0.942300 -0.670262
# 4 -0.727734 -0.860563      0.383327  1.228418
# 5 -1.478792 -0.860563      0.840170  0.241615
# 6  0.774383  1.366144      0.741615 -0.184280
# 7 -0.727734  1.366144      0.417750 -1.014413
# 8 -0.620439 -1.107975      0.278873  0.832466
# 9 -1.264204 -0.365739      1.430696 -0.018864

# %%
def evaluate_regression_model(model,X_test,y_test):
    pred = model.predict(X_test)
    print("R Square Error : ",r2_score(y_test,pred))
    print("Mean Absolute Error (MAE) : ",mean_absolute_error(y_test,pred))
    print("Root Mean Squared Error (RMSE) : ",np.sqrt(mean_absolute_error(y_test,pred)))

# %%
evaluate_regression_model(knn_model, X_test, y_test)
# Out:
# R Square Error :  0.34199020636586197
# Mean Absolute Error (MAE) :  8.733333333333334
# Root Mean Squared Error (RMSE) :  2.955221367906867
