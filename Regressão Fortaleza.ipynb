# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import sklearn.cluster as kMeans
import numpy as np
import statsmodels.api as smf
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
#metricas de avaliação
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("/content/dengue_35-20 fortaleza.csv", sep=",")
df
# Out:
#     data_iniSE      SE  casos_est  casos_est_min  casos_est_max  casos  \
# 0   2024-05-05  202419      263.0             93            788     25
# 1   2024-04-28  202418      292.0            173            592    118
# 2   2024-04-21  202417      300.5            226            501    187
# 3   2024-04-14  202416      365.0            321            470    297
# 4   2024-04-07  202415      561.0            537            613    522
# 5   2024-03-31  202414      586.0            570            614    563
# 6   2024-03-24  202413      406.0            395            427    392
# 7   2024-03-17  202412      463.0            457            475    455
# 8   2024-03-10  202411      483.0            478            494    478
# 9   2024-03-03  202410      545.0            542            554    542
# 10  2024-02-25  202409      428.0            428            428    428
# 11  2024-02-18  202408      376.0            376            376    376
# 12  2024-02-11  202407      316.0            316            316    316
# 13  2024-02-04  202406      230.0            230            230    230
# 14  2024-01-28  202405      248.0            248            248    248
# 15  2024-01-21  202404      184.0            184            184    184
# 16  2024-01-14  202403      181.0            181            181    181
# 17  2024-01-07  202402      135.0            135            135    135
# 18  2023-12-31  202401      143.0            143            143    143
# 19  2023-12-24  202352       34.0             34             34     34
# 20  2023-12-17  202351       27.0             27             27     27
# 21  2023-12-10  202350       72.0             72             72     72
# 22  2023-12-03  202349       95.0             95             95     95
# 23  2023-11-26  202348       98.0             98             98     98
# 24  2023-11-19  202347      120.0            120            120    120
# 25  2023-11-12  202346       87.0             87             87     87
# 26  2023-11-05  202345      108.0            108            108    108
# 27  2023-10-29  202344      118.0            118            118    118
# 28  2023-10-22  202343      118.0            118            118    118
# 29  2023-10-15  202342      137.0            137            137    137
# 30  2023-10-08  202341      139.0            139            139    139
# 31  2023-10-01  202340      174.0            174            174    174
# 32  2023-09-24  202339      145.0            145            145    145
# 33  2023-09-17  202338      169.0            169            169    169
# 34  2023-09-10  202337      168.0            168            168    168
# 35  2023-09-03  202336      208.0            208            208    208
# 36  2023-08-27  202335      201.0            201            201    201
#
#            p_rt1  p_inc100k  Localidade_id  nivel  ...    umidmed    umidmin  \
# 0   4.659740e-03  10.130358              0      1  ...  80.711254  80.237182
# 1   1.148245e-05  11.247394              0      1  ...  87.276541  86.167180
# 2   2.439493e-12  11.574801              0      1  ...  85.237595  84.198522
# 3   2.079876e-07  14.059242              0      1  ...  86.518861  84.641308
# 4   9.963872e-01  21.608862              0      3  ...  87.234853  85.411612
# 5   9.999303e-01  22.571825              0      1  ...  84.341718  83.691123
# 6   4.715244e-03  15.638499              0      1  ...  88.569791  86.154237
# 7   2.414437e-01  17.834053              0      1  ...  84.939883  83.427196
# 8   9.319842e-01  18.604422              0      1  ...  86.565718  84.363271
# 9   1.000000e+00  20.992567              0      3  ...  81.933883  81.365461
# 10  9.999933e-01  16.485907              0      3  ...  86.717874  84.979635
# 11  9.999983e-01  14.482945              0      3  ...  85.085193  84.062718
# 12  9.999413e-01  12.171837              0      1  ...  84.707208  83.928550
# 13  9.419492e-01   8.859248              0      1  ...  78.714073  78.369635
# 14  9.999260e-01   9.552581              0      3  ...  75.526337  74.565351
# 15  9.862755e-01   7.087399              0      3  ...  77.418077  77.090042
# 16  9.999879e-01   6.971843              0      1  ...  78.470939  77.534893
# 17  9.999995e-01   5.199994              0      1  ...  77.653739  76.987920
# 18  1.000000e+00   5.508141              0      1  ...  80.986075  79.661418
# 19  6.081052e-04   1.309628              0      1  ...  79.934828  76.765887
# 20  3.024376e-09   1.039999              0      1  ...  79.063176  76.548805
# 21  1.542317e-02   2.773330              0      1  ...  76.038369  67.626502
# 22  2.581891e-01   3.659255              0      1  ...  73.772622  55.443224
# 23  3.862473e-01   3.774810              0      1  ...        NaN        NaN
# 24  8.217092e-01   4.622217              0      1  ...        NaN        NaN
# 25  2.594922e-02   3.351107              0      1  ...  79.022647  78.113207
# 26  1.628159e-01   4.159995              0      1  ...  73.516632  69.865381
# 27  1.671815e-01   4.545180              0      1  ...  77.109717  71.139632
# 28  4.374938e-02   4.545180              0      1  ...  77.925172  73.896237
# 29  1.401572e-01   5.277031              0      1  ...  76.632077  74.158368
# 30  1.302814e-01   5.354068              0      1  ...  78.153370  74.662743
# 31  6.935132e-01   6.702214              0      1  ...  76.299059  72.136944
# 32  3.321616e-02   5.585178              0      1  ...  78.747137  72.475238
# 33  9.501722e-02   6.509622              0      1  ...  79.001807  76.002810
# 34  3.573268e-02   6.471103              0      1  ...  76.459191  66.929103
# 35  6.334737e-01   8.011842              0      1  ...        NaN        NaN
# 36  6.313534e-01   7.742213              0      1  ...        NaN        NaN
#
#       tempmed    tempmax  casprov  casprov_est  casprov_est_min  \
# 0   28.488889  28.555556      NaN          NaN              NaN
# 1   27.304545  27.454545      NaN          NaN              NaN
# 2   27.113636  27.181818      NaN          NaN              NaN
# 3   27.684211  27.894737      NaN          NaN              NaN
# 4   27.736842  28.000000      NaN          NaN              NaN
# 5   28.125000  28.200000      NaN          NaN              NaN
# 6   27.361111  27.611111      NaN          NaN              NaN
# 7   28.175000  28.250000      NaN          NaN              NaN
# 8   27.900000  28.000000      NaN          NaN              NaN
# 9   28.156863  28.176471      NaN          NaN              NaN
# 10  27.075000  27.500000      NaN          NaN              NaN
# 11  27.681818  27.818182      NaN          NaN              NaN
# 12  27.841270  28.000000      NaN          NaN              NaN
# 13  29.000000  29.000000      NaN          NaN              NaN
# 14  28.928571  29.000000      NaN          NaN              NaN
# 15  28.714286  28.714286      NaN          NaN              NaN
# 16  28.000000  28.000000      NaN          NaN              NaN
# 17  28.214286  28.285714      NaN          NaN              NaN
# 18  27.950000  28.050000      NaN          NaN              NaN
# 19  28.101449  28.695652      NaN          NaN              NaN
# 20  27.978261  28.391304      NaN          NaN              NaN
# 21  27.919355  29.516129      NaN          NaN              NaN
# 22  28.402777  31.500000      NaN          NaN              NaN
# 23        NaN        NaN      NaN          NaN              NaN
# 24        NaN        NaN      NaN          NaN              NaN
# 25  27.230769  27.307692      NaN          NaN              NaN
# 26  27.800000  28.450000      NaN          NaN              NaN
# 27  27.507246  28.173913      NaN          NaN              NaN
# 28  27.015873  27.952381      NaN          NaN              NaN
# 29  27.119318  27.545455      NaN          NaN              NaN
# 30  27.193750  27.600000      NaN          NaN              NaN
# 31  27.125000  27.714286      NaN          NaN              NaN
# 32  26.916667  27.944444      NaN          NaN              NaN
# 33  27.142045  27.681818      NaN          NaN              NaN
# 34  27.333333  29.000000      NaN          NaN              NaN
# 35        NaN        NaN      NaN          NaN              NaN
# 36        NaN        NaN      NaN          NaN              NaN
#
#     casprov_est_max  casconf  notif_accum_year
# 0               NaN      NaN              8038
# 1               NaN      NaN              8038
# 2               NaN      NaN              8038
# 3               NaN      NaN              8038
# 4               NaN      NaN              8038
# 5               NaN      NaN              8038
# 6               NaN      NaN              8038
# 7               NaN      NaN              8038
# 8               NaN      NaN              8038
# 9               NaN      NaN              8038
# 10              NaN      NaN              8038
# 11              NaN      NaN              8038
# 12              NaN      NaN              8038
# 13              NaN      NaN              8038
# 14              NaN      NaN              8038
# 15              NaN      NaN              8038
# 16              NaN      NaN              8038
# 17              NaN      NaN              8038
# 18              NaN      NaN              8038
# 19              NaN      NaN              8038
# 20              NaN      NaN              8038
# 21              NaN      NaN              8038
# 22              NaN      NaN              8038
# 23              NaN      NaN              8038
# 24              NaN      NaN              8038
# 25              NaN      NaN              8038
# 26              NaN      NaN              8038
# 27              NaN      NaN              8038
# 28              NaN      NaN              8038
# 29              NaN      NaN              8038
# 30              NaN      NaN              8038
# 31              NaN      NaN              8038
# 32              NaN      NaN              8038
# 33              NaN      NaN              8038
# 34              NaN      NaN              8038
# 35              NaN      NaN              8038
# 36              NaN      NaN              8038
#
# [37 rows x 30 columns]

# %%
df["data_iniSE"] = pd.to_datetime(df["data_iniSE"])
mes = df["data_iniSE"].dt.month
dia = df["data_iniSE"].dt.day
#ano = df["data_iniSE"].dt.year
casos = df["casos"]
tempmed = df["tempmed"]
umidmed = df["umidmed"]

# %%
df1 = pd.DataFrame({'Dia': dia,'Mês':mes, 'Casos': casos, 'TemperaturaM':tempmed, 'UmidadeM':umidmed})

# %%
df1
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5     25     28.488889  80.711254
# 1    28    4    118     27.304545  87.276541
# 2    21    4    187     27.113636  85.237595
# 3    14    4    297     27.684211  86.518861
# 4     7    4    522     27.736842  87.234853
# 5    31    3    563     28.125000  84.341718
# 6    24    3    392     27.361111  88.569791
# 7    17    3    455     28.175000  84.939883
# 8    10    3    478     27.900000  86.565718
# 9     3    3    542     28.156863  81.933883
# 10   25    2    428     27.075000  86.717874
# 11   18    2    376     27.681818  85.085193
# 12   11    2    316     27.841270  84.707208
# 13    4    2    230     29.000000  78.714073
# 14   28    1    248     28.928571  75.526337
# 15   21    1    184     28.714286  77.418077
# 16   14    1    181     28.000000  78.470939
# 17    7    1    135     28.214286  77.653739
# 18   31   12    143     27.950000  80.986075
# 19   24   12     34     28.101449  79.934828
# 20   17   12     27     27.978261  79.063176
# 21   10   12     72     27.919355  76.038369
# 22    3   12     95     28.402777  73.772622
# 23   26   11     98           NaN        NaN
# 24   19   11    120           NaN        NaN
# 25   12   11     87     27.230769  79.022647
# 26    5   11    108     27.800000  73.516632
# 27   29   10    118     27.507246  77.109717
# 28   22   10    118     27.015873  77.925172
# 29   15   10    137     27.119318  76.632077
# 30    8   10    139     27.193750  78.153370
# 31    1   10    174     27.125000  76.299059
# 32   24    9    145     26.916667  78.747137
# 33   17    9    169     27.142045  79.001807
# 34   10    9    168     27.333333  76.459191
# 35    3    9    208           NaN        NaN
# 36   27    8    201           NaN        NaN

# %%
sns.countplot(x="Casos", data=df1);

# %%
columns_to_remove = ["SE","id","casos_est",
                     "casos_est_min","casos_est_max",
                     "p_rt1","p_inc100k",
                     "Localidade_id","nivel",
                     "casprov","casprov_est","casprov_est_min",
                     "casprov_est_max","casconf","tweet","Rt","pop","receptivo",
                     "transmissao","nivel_inc","notif_accum_year","versao_modelo" ]
df = df.drop(columns_to_remove, axis=1)
df.sample(4)
# Out:
#    data_iniSE  casos    tempmin    umidmax    umidmed    umidmin    tempmed  \
# 17 2024-01-07    135  28.142857  78.319558  77.653739  76.987920  28.214286
# 12 2024-02-11    316  27.666667  85.566030  84.707208  83.928550  27.841270
# 28 2023-10-22    118  26.380952  80.632535  77.925172  73.896237  27.015873
# 20 2023-12-17     27  27.521739  80.892031  79.063176  76.548805  27.978261
#
#       tempmax
# 17  28.285714
# 12  28.000000
# 28  27.952381
# 20  28.391304

# %%
df.isnull().sum()
# Out:
# data_iniSE    0
# casos         0
# tempmin       4
# umidmax       0
# umidmed       4
# umidmin       4
# tempmed       4
# tempmax       4
# dtype: int64

# %%
df1_treino = df1.dropna(subset=["TemperaturaM","UmidadeM"])

# %%
X = df1_treino.drop('Casos',axis=1)
y= df1_treino['Casos']

# %%
X
# Out:
#     Dia  Mês  TemperaturaM   UmidadeM
# 0     5    5     28.488889  80.711254
# 1    28    4     27.304545  87.276541
# 2    21    4     27.113636  85.237595
# 3    14    4     27.684211  86.518861
# 4     7    4     27.736842  87.234853
# 5    31    3     28.125000  84.341718
# 6    24    3     27.361111  88.569791
# 7    17    3     28.175000  84.939883
# 8    10    3     27.900000  86.565718
# 9     3    3     28.156863  81.933883
# 10   25    2     27.075000  86.717874
# 11   18    2     27.681818  85.085193
# 12   11    2     27.841270  84.707208
# 13    4    2     29.000000  78.714073
# 14   28    1     28.928571  75.526337
# 15   21    1     28.714286  77.418077
# 16   14    1     28.000000  78.470939
# 17    7    1     28.214286  77.653739
# 18   31   12     27.950000  80.986075
# 19   24   12     28.101449  79.934828
# 20   17   12     27.978261  79.063176
# 21   10   12     27.919355  76.038369
# 22    3   12     28.402777  73.772622
# 25   12   11     27.230769  79.022647
# 26    5   11     27.800000  73.516632
# 27   29   10     27.507246  77.109717
# 28   22   10     27.015873  77.925172
# 29   15   10     27.119318  76.632077
# 30    8   10     27.193750  78.153370
# 31    1   10     27.125000  76.299059
# 32   24    9     26.916667  78.747137
# 33   17    9     27.142045  79.001807
# 34   10    9     27.333333  76.459191

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.3,random_state= 42)

# %%
sca = preprocessing.StandardScaler()

# %%
cols = X.columns
cols
# Out:
# Index(['Dia', 'Mês', 'TemperaturaM', 'UmidadeM'], dtype='object')

# %%
df["data_iniSE"].dtype
#float_cols = X_train
# Out:
# dtype('<M8[ns]')

# %%
float_cols = X_train

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
df.data_iniSE = df['data_iniSE']

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
X_train
df1.drop([12,16,23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5     25     28.488889  80.711254
# 1    28    4    118     27.304545  87.276541
# 2    21    4    187     27.113636  85.237595
# 3    14    4    297     27.684211  86.518861
# 4     7    4    522     27.736842  87.234853
# 5    31    3    563     28.125000  84.341718
# 6    24    3    392     27.361111  88.569791
# 7    17    3    455     28.175000  84.939883
# 8    10    3    478     27.900000  86.565718
# 9     3    3    542     28.156863  81.933883
# 10   25    2    428     27.075000  86.717874
# 11   18    2    376     27.681818  85.085193
# 13    4    2    230     29.000000  78.714073
# 14   28    1    248     28.928571  75.526337
# 15   21    1    184     28.714286  77.418077
# 17    7    1    135     28.214286  77.653739
# 18   31   12    143     27.950000  80.986075
# 19   24   12     34     28.101449  79.934828
# 20   17   12     27     27.978261  79.063176
# 21   10   12     72     27.919355  76.038369
# 22    3   12     95     28.402777  73.772622
# 25   12   11     87     27.230769  79.022647
# 26    5   11    108     27.800000  73.516632
# 27   29   10    118     27.507246  77.109717
# 28   22   10    118     27.015873  77.925172
# 29   15   10    137     27.119318  76.632077
# 30    8   10    139     27.193750  78.153370
# 31    1   10    174     27.125000  76.299059
# 32   24    9    145     26.916667  78.747137
# 33   17    9    169     27.142045  79.001807
# 34   10    9    168     27.333333  76.459191

# %%
y_train
df1.drop([23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5     25     28.488889  80.711254
# 1    28    4    118     27.304545  87.276541
# 2    21    4    187     27.113636  85.237595
# 3    14    4    297     27.684211  86.518861
# 4     7    4    522     27.736842  87.234853
# 5    31    3    563     28.125000  84.341718
# 6    24    3    392     27.361111  88.569791
# 7    17    3    455     28.175000  84.939883
# 8    10    3    478     27.900000  86.565718
# 9     3    3    542     28.156863  81.933883
# 10   25    2    428     27.075000  86.717874
# 11   18    2    376     27.681818  85.085193
# 12   11    2    316     27.841270  84.707208
# 13    4    2    230     29.000000  78.714073
# 14   28    1    248     28.928571  75.526337
# 15   21    1    184     28.714286  77.418077
# 16   14    1    181     28.000000  78.470939
# 17    7    1    135     28.214286  77.653739
# 18   31   12    143     27.950000  80.986075
# 19   24   12     34     28.101449  79.934828
# 20   17   12     27     27.978261  79.063176
# 21   10   12     72     27.919355  76.038369
# 22    3   12     95     28.402777  73.772622
# 25   12   11     87     27.230769  79.022647
# 26    5   11    108     27.800000  73.516632
# 27   29   10    118     27.507246  77.109717
# 28   22   10    118     27.015873  77.925172
# 29   15   10    137     27.119318  76.632077
# 30    8   10    139     27.193750  78.153370
# 31    1   10    174     27.125000  76.299059
# 32   24    9    145     26.916667  78.747137
# 33   17    9    169     27.142045  79.001807
# 34   10    9    168     27.333333  76.459191

# %%
df
df1.drop([12,16,23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5     25     28.488889  80.711254
# 1    28    4    118     27.304545  87.276541
# 2    21    4    187     27.113636  85.237595
# 3    14    4    297     27.684211  86.518861
# 4     7    4    522     27.736842  87.234853
# 5    31    3    563     28.125000  84.341718
# 6    24    3    392     27.361111  88.569791
# 7    17    3    455     28.175000  84.939883
# 8    10    3    478     27.900000  86.565718
# 9     3    3    542     28.156863  81.933883
# 10   25    2    428     27.075000  86.717874
# 11   18    2    376     27.681818  85.085193
# 13    4    2    230     29.000000  78.714073
# 14   28    1    248     28.928571  75.526337
# 15   21    1    184     28.714286  77.418077
# 17    7    1    135     28.214286  77.653739
# 18   31   12    143     27.950000  80.986075
# 19   24   12     34     28.101449  79.934828
# 20   17   12     27     27.978261  79.063176
# 21   10   12     72     27.919355  76.038369
# 22    3   12     95     28.402777  73.772622
# 25   12   11     87     27.230769  79.022647
# 26    5   11    108     27.800000  73.516632
# 27   29   10    118     27.507246  77.109717
# 28   22   10    118     27.015873  77.925172
# 29   15   10    137     27.119318  76.632077
# 30    8   10    139     27.193750  78.153370
# 31    1   10    174     27.125000  76.299059
# 32   24    9    145     26.916667  78.747137
# 33   17    9    169     27.142045  79.001807
# 34   10    9    168     27.333333  76.459191

# %%
X_train = sca.fit_transform(X_train)
X_train = pd.DataFrame(X_train,columns=cols)
X_test = sca.transform(X_test)
X_test = pd.DataFrame(X_test,columns=cols)

# %%
knn_model = KNeighborsRegressor(n_neighbors=3)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
X_train
# Out:
#          Dia       Mês  TemperaturaM  UmidadeM
# 0  -1.049616 -0.613151      0.093143  1.370976
# 1  -0.298557 -1.355387      0.561182 -0.496159
# 2   1.525441 -0.860563      0.783501  0.754599
# 3  -1.371498 -1.107975      2.339732 -0.444360
# 4   0.130619 -1.107975     -0.004720  0.912995
# 5  -1.264204  1.118732      0.205472 -1.551665
# 6   1.203559 -0.613151     -0.675718  1.379858
# 7   0.452501 -0.613151     -1.015260  0.945464
# 8  -1.693380  0.871320     -0.995049 -0.958874
# 9  -0.298557 -0.613151     -0.000465  1.218435
# 10 -0.191263  0.871320     -1.005154 -0.887925
# 11 -0.513145  1.118732     -0.806933 -0.378619
# 12  0.774383  0.623908     -1.365580 -0.437315
# 13 -1.478792  1.366144      1.277542 -1.497126
# 14  1.525441  1.366144      0.472255  0.039686
# 15  1.310853  0.871320     -0.315205 -0.786165
# 16  0.774383 -0.860563     -0.575114  1.655382
# 17  0.023325  1.366144      0.522518 -0.369984
# 18 -0.727734  0.623908     -0.624518 -0.924758
# 19  0.023325 -0.860563      0.872429  0.882037
# 20  0.881677 -1.107975     -1.083977  1.260835
# 21  1.203559 -1.355387      2.212693 -1.123501
# 22 -0.942322  0.871320     -0.872774 -0.563817

# %%
y_pred = knn_model.predict(X_test)
y_pred
# Out:
# array([123.        , 219.66666667, 133.33333333, 288.66666667,
#        424.66666667, 386.        ,  96.        ,  76.66666667,
#        398.33333333, 288.66666667])

# %%
y_train
# Out:
# 4     522
# 16    181
# 5     563
# 13    230
# 11    376
# 26    108
# 1     118
# 2     187
# 31    174
# 3     297
# 29    137
# 25     87
# 32    145
# 22     95
# 18    143
# 27    118
# 6     392
# 20     27
# 34    168
# 7     455
# 10    428
# 14    248
# 30    139
# Name: Casos, dtype: int64

# %%
#Dados nulos
df1.isnull().sum()
# Out:
# Dia             0
# Mês             0
# Casos           0
# TemperaturaM    4
# UmidadeM        4
# dtype: int64

# %%
sns.countplot(x="Casos", data=df1);

# %%
fig = px.scatter(df1, x="Casos",
                 y="Mês",
                 title= "Numeros de Casos")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="67200d31-f38e-47fb-b045-e19db8bba1e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67200d31-f38e-47fb-b045-e19db8bba1e1")) {                    Plotly.newPlot(                        "67200d31-f38e-47fb-b045-e19db8bba1e1",                        [{"hovertemplate":"Casos=%{x}\u003cbr\u003eM\u00eas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[25,118,187,297,522,563,392,455,478,542,428,376,316,230,248,184,181,135,143,34,27,72,95,98,120,87,108,118,118,137,139,174,145,169,168,208,201],"xaxis":"x","y":[5,4,4,4,4,3,3,3,3,3,2,2,2,2,1,1,1,1,12,12,12,12,12,11,11,11,11,10,10,10,10,10,9,9,9,9,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode": ...

# %%
fig = px.scatter(x=y_test, y=y_pred, title="Casos por Mês", trendline="ols", labels= {"X":"Casos","y":"Mês"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5057b4b6-10c4-4816-96e6-f7568c658c4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5057b4b6-10c4-4816-96e6-f7568c658c4b")) {                    Plotly.newPlot(                        "5057b4b6-10c4-4816-96e6-f7568c658c4b",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eM\u00eas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[169,184,118,135,478,542,34,72,316,25],"xaxis":"x","y":[123.0,219.66666666666666,133.33333333333334,288.6666666666667,424.6666666666667,386.0,96.0,76.66666666666667,398.3333333333333,288.6666666666667],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ey = 0.562127 * x + 126.971\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.587795\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003eM\u00eas=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[25,34,72,118,135,169,184,316,478,542],"xaxis":"x","y":[141.02433418021403,146.08347292063132,167.44428093572657,193.3021011645261,202.85825211864767,221.9705540268908,230.4024519275863,304.60315345370674,395.66765078121813,431.64374849085226],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444 ...

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12,8))

# %%
sns.countplot(x="Casos", data=df1)
plt.title("Nível de casos")
# Out:
# Text(0.5, 1.0, 'Nível de casos')

# %%
decision_tree = DecisionTreeClassifier()

# %%
df1
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5     25     28.488889  80.711254
# 1    28    4    118     27.304545  87.276541
# 2    21    4    187     27.113636  85.237595
# 3    14    4    297     27.684211  86.518861
# 4     7    4    522     27.736842  87.234853
# 5    31    3    563     28.125000  84.341718
# 6    24    3    392     27.361111  88.569791
# 7    17    3    455     28.175000  84.939883
# 8    10    3    478     27.900000  86.565718
# 9     3    3    542     28.156863  81.933883
# 10   25    2    428     27.075000  86.717874
# 11   18    2    376     27.681818  85.085193
# 12   11    2    316     27.841270  84.707208
# 13    4    2    230     29.000000  78.714073
# 14   28    1    248     28.928571  75.526337
# 15   21    1    184     28.714286  77.418077
# 16   14    1    181     28.000000  78.470939
# 17    7    1    135     28.214286  77.653739
# 18   31   12    143     27.950000  80.986075
# 19   24   12     34     28.101449  79.934828
# 20   17   12     27     27.978261  79.063176
# 21   10   12     72     27.919355  76.038369
# 22    3   12     95     28.402777  73.772622
# 23   26   11     98           NaN        NaN
# 24   19   11    120           NaN        NaN
# 25   12   11     87     27.230769  79.022647
# 26    5   11    108     27.800000  73.516632
# 27   29   10    118     27.507246  77.109717
# 28   22   10    118     27.015873  77.925172
# 29   15   10    137     27.119318  76.632077
# 30    8   10    139     27.193750  78.153370
# 31    1   10    174     27.125000  76.299059
# 32   24    9    145     26.916667  78.747137
# 33   17    9    169     27.142045  79.001807
# 34   10    9    168     27.333333  76.459191
# 35    3    9    208           NaN        NaN
# 36   27    8    201           NaN        NaN

# %%
X_test
# Out:
#         Dia       Mês  TemperaturaM  UmidadeM
# 0  0.023325  0.623908     -0.964733 -0.383059
# 1  0.452501 -1.355387      1.831575 -0.720469
# 2  0.559795  0.871320     -1.189137 -0.612434
# 3 -1.049616 -1.355387      0.942300 -0.670262
# 4 -0.727734 -0.860563      0.383327  1.228418
# 5 -1.478792 -0.860563      0.840170  0.241615
# 6  0.774383  1.366144      0.741615 -0.184280
# 7 -0.727734  1.366144      0.417750 -1.014413
# 8 -0.620439 -1.107975      0.278873  0.832466
# 9 -1.264204 -0.365739      1.430696 -0.018864

# %%
def evaluate_regression_model(model,X_test,y_test):
    pred = model.predict(X_test)
    print("R Square Error : ",r2_score(y_test,pred))
    print("Mean Absolute Error (MAE) : ",mean_absolute_error(y_test,pred))
    print("Root Mean Squared Error (RMSE) : ",np.sqrt(mean_absolute_error(y_test,pred)))

# %%
evaluate_regression_model(knn_model, X_test, y_test)
# Out:
# R Square Error :  0.5420863689719202
# Mean Absolute Error (MAE) :  87.26666666666668
# Root Mean Squared Error (RMSE) :  9.34166294974651
