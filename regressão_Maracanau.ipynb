# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import sklearn.cluster as kMeans
import numpy as np
import statsmodels.api as smf
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
#metricas de avaliação
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("/content/dengue_35-20 maracanau.csv", sep=",")
df
# Out:
#     data_iniSE      SE  casos_est  casos_est_min  casos_est_max  casos  \
# 0   2024-05-05  202419       15.0              0            152      0
# 1   2024-04-28  202418       14.0              3             93      3
# 2   2024-04-21  202417       22.0             16             46     16
# 3   2024-04-14  202416       40.0             36             52     36
# 4   2024-04-07  202415       62.0             59             72     59
# 5   2024-03-31  202414       30.0             28             38     28
# 6   2024-03-24  202413       20.0             18             28     18
# 7   2024-03-17  202412       30.0             29             37     29
# 8   2024-03-10  202411       27.0             26             33     26
# 9   2024-03-03  202410       41.0             41             49     41
# 10  2024-02-25  202409       73.0             73             73     73
# 11  2024-02-18  202408       86.0             86             86     86
# 12  2024-02-11  202407       75.0             75             75     75
# 13  2024-02-04  202406       26.0             26             26     26
# 14  2024-01-28  202405       32.0             32             32     32
# 15  2024-01-21  202404       11.0             11             11     11
# 16  2024-01-14  202403        4.0              4              4      4
# 17  2024-01-07  202402       12.0             12             12     12
# 18  2023-12-31  202401        6.0              6              6      6
# 19  2023-12-24  202352        1.0              1              1      1
# 20  2023-12-17  202351        1.0              1              1      1
# 21  2023-12-10  202350        6.0              6              6      6
# 22  2023-12-03  202349        3.0              3              3      3
# 23  2023-11-26  202348        2.0              2              2      2
# 24  2023-11-19  202347        8.0              8              8      8
# 25  2023-11-12  202346       10.0             10             10     10
# 26  2023-11-05  202345       24.0             24             24     24
# 27  2023-10-29  202344       11.0             11             11     11
# 28  2023-10-22  202343       14.0             14             14     14
# 29  2023-10-15  202342       13.0             13             13     13
# 30  2023-10-08  202341       12.0             12             12     12
# 31  2023-10-01  202340       14.0             14             14     14
# 32  2023-09-24  202339        7.0              7              7      7
# 33  2023-09-17  202338       16.0             16             16     16
# 34  2023-09-10  202337       13.0             13             13     13
# 35  2023-09-03  202336       14.0             14             14     14
# 36  2023-08-27  202335       11.0             11             11     11
#
#        p_rt1  p_inc100k  Localidade_id  nivel  ...    umidmed    umidmin  \
# 0   0.038737   6.490107              0      1  ...  80.711254  80.237182
# 1   0.000227   6.057433              0      1  ...  87.276541  86.167180
# 2   0.002887   9.518824              0      1  ...  85.237595  84.198522
# 3   0.689829  17.306952              0      1  ...  86.518861  84.641308
# 4   0.999898  26.825775              0      1  ...  87.234853  85.411612
# 5   0.629629  12.980214              0      1  ...  84.341718  83.691123
# 6   0.031872   8.653476              0      1  ...  88.569791  86.154237
# 7   0.024316  12.980214              0      1  ...  84.939883  83.427196
# 8   0.000022  11.682193              0      1  ...  86.565718  84.363271
# 9   0.000964  17.739626              0      1  ...  81.933883  81.365461
# 10  0.811595  31.585188              0      1  ...  86.717874  84.979635
# 11  0.999968  37.209946              0      3  ...  85.085193  84.062718
# 12  1.000000  32.450535              0      3  ...  84.707208  83.928550
# 13  0.956757  11.249518              0      3  ...  78.714073  78.369635
# 14  0.999889  13.845561              0      1  ...  75.526337  74.565351
# 15  0.770692   4.759412              0      1  ...  77.418077  77.090042
# 16  0.269881   1.730695              0      1  ...  78.470939  77.534893
# 17  0.992935   5.192086              0      1  ...  77.653739  76.987920
# 18  0.893178   2.596043              0      1  ...  80.986075  79.661418
# 19  0.084768   0.432674              0      1  ...  79.934828  76.765887
# 20  0.078778   0.432674              0      1  ...  79.063176  76.548805
# 21  0.693852   2.596043              0      1  ...  76.038369  67.626502
# 22  0.066732   1.298021              0      1  ...  73.772622  55.443224
# 23  0.001253   0.865348              0      1  ...        NaN        NaN
# 24  0.048266   3.461390              0      1  ...        NaN        NaN
# 25  0.159033   4.326738              0      1  ...  79.022647  78.113207
# 26  0.961271  10.384172              0      1  ...  73.516632  69.865381
# 27  0.349075   4.759412              0      1  ...  77.109717  71.139632
# 28  0.614329   6.057433              0      1  ...  77.925172  73.896237
# 29  0.596178   5.624759              0      1  ...  76.632077  74.158368
# 30  0.544759   5.192086              0      1  ...  78.153370  74.662743
# 31  0.594273   6.057433              0      1  ...  76.299059  72.136944
# 32  0.070143   3.028717              0      1  ...  78.747137  72.475238
# 33  0.712359   6.922781              0      1  ...  79.001807  76.002810
# 34  0.538456   5.624759              0      1  ...  76.459191  66.929103
# 35  0.550230   6.057433              0      1  ...        NaN        NaN
# 36  0.188179   4.759412              0      1  ...        NaN        NaN
#
#       tempmed    tempmax  casprov  casprov_est  casprov_est_min  \
# 0   28.488889  28.555556      NaN          NaN              NaN
# 1   27.304545  27.454545      NaN          NaN              NaN
# 2   27.113636  27.181818      NaN          NaN              NaN
# 3   27.684211  27.894737      NaN          NaN              NaN
# 4   27.736842  28.000000      NaN          NaN              NaN
# 5   28.125000  28.200000      NaN          NaN              NaN
# 6   27.361111  27.611111      NaN          NaN              NaN
# 7   28.175000  28.250000      NaN          NaN              NaN
# 8   27.900000  28.000000      NaN          NaN              NaN
# 9   28.156863  28.176471      NaN          NaN              NaN
# 10  27.075000  27.500000      NaN          NaN              NaN
# 11  27.681818  27.818182      NaN          NaN              NaN
# 12  27.841270  28.000000      NaN          NaN              NaN
# 13  29.000000  29.000000      NaN          NaN              NaN
# 14  28.928571  29.000000      NaN          NaN              NaN
# 15  28.714286  28.714286      NaN          NaN              NaN
# 16  28.000000  28.000000      NaN          NaN              NaN
# 17  28.214286  28.285714      NaN          NaN              NaN
# 18  27.950000  28.050000      NaN          NaN              NaN
# 19  28.101449  28.695652      NaN          NaN              NaN
# 20  27.978261  28.391304      NaN          NaN              NaN
# 21  27.919355  29.516129      NaN          NaN              NaN
# 22  28.402777  31.500000      NaN          NaN              NaN
# 23        NaN        NaN      NaN          NaN              NaN
# 24        NaN        NaN      NaN          NaN              NaN
# 25  27.230769  27.307692      NaN          NaN              NaN
# 26  27.800000  28.450000      NaN          NaN              NaN
# 27  27.507246  28.173913      NaN          NaN              NaN
# 28  27.015873  27.952381      NaN          NaN              NaN
# 29  27.119318  27.545455      NaN          NaN              NaN
# 30  27.193750  27.600000      NaN          NaN              NaN
# 31  27.125000  27.714286      NaN          NaN              NaN
# 32  26.916667  27.944444      NaN          NaN              NaN
# 33  27.142045  27.681818      NaN          NaN              NaN
# 34  27.333333  29.000000      NaN          NaN              NaN
# 35        NaN        NaN      NaN          NaN              NaN
# 36        NaN        NaN      NaN          NaN              NaN
#
#     casprov_est_max  casconf  notif_accum_year
# 0               NaN      NaN               761
# 1               NaN      NaN               761
# 2               NaN      NaN               761
# 3               NaN      NaN               761
# 4               NaN      NaN               761
# 5               NaN      NaN               761
# 6               NaN      NaN               761
# 7               NaN      NaN               761
# 8               NaN      NaN               761
# 9               NaN      NaN               761
# 10              NaN      NaN               761
# 11              NaN      NaN               761
# 12              NaN      NaN               761
# 13              NaN      NaN               761
# 14              NaN      NaN               761
# 15              NaN      NaN               761
# 16              NaN      NaN               761
# 17              NaN      NaN               761
# 18              NaN      NaN               761
# 19              NaN      NaN               761
# 20              NaN      NaN               761
# 21              NaN      NaN               761
# 22              NaN      NaN               761
# 23              NaN      NaN               761
# 24              NaN      NaN               761
# 25              NaN      NaN               761
# 26              NaN      NaN               761
# 27              NaN      NaN               761
# 28              NaN      NaN               761
# 29              NaN      NaN               761
# 30              NaN      NaN               761
# 31              NaN      NaN               761
# 32              NaN      NaN               761
# 33              NaN      NaN               761
# 34              NaN      NaN               761
# 35              NaN      NaN               761
# 36              NaN      NaN               761
#
# [37 rows x 30 columns]

# %%
df["data_iniSE"] = pd.to_datetime(df["data_iniSE"])
mes = df["data_iniSE"].dt.month
dia = df["data_iniSE"].dt.day
#ano = df["data_iniSE"].dt.year
casos = df["casos"]
tempmed = df["tempmed"]
umidmed = df["umidmed"]

# %%
df1 = pd.DataFrame({'Dia': dia,'Mês':mes, 'Casos': casos, 'TemperaturaM':tempmed, 'UmidadeM':umidmed})

# %%
df1
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      3     27.304545  87.276541
# 2    21    4     16     27.113636  85.237595
# 3    14    4     36     27.684211  86.518861
# 4     7    4     59     27.736842  87.234853
# 5    31    3     28     28.125000  84.341718
# 6    24    3     18     27.361111  88.569791
# 7    17    3     29     28.175000  84.939883
# 8    10    3     26     27.900000  86.565718
# 9     3    3     41     28.156863  81.933883
# 10   25    2     73     27.075000  86.717874
# 11   18    2     86     27.681818  85.085193
# 12   11    2     75     27.841270  84.707208
# 13    4    2     26     29.000000  78.714073
# 14   28    1     32     28.928571  75.526337
# 15   21    1     11     28.714286  77.418077
# 16   14    1      4     28.000000  78.470939
# 17    7    1     12     28.214286  77.653739
# 18   31   12      6     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      1     27.978261  79.063176
# 21   10   12      6     27.919355  76.038369
# 22    3   12      3     28.402777  73.772622
# 23   26   11      2           NaN        NaN
# 24   19   11      8           NaN        NaN
# 25   12   11     10     27.230769  79.022647
# 26    5   11     24     27.800000  73.516632
# 27   29   10     11     27.507246  77.109717
# 28   22   10     14     27.015873  77.925172
# 29   15   10     13     27.119318  76.632077
# 30    8   10     12     27.193750  78.153370
# 31    1   10     14     27.125000  76.299059
# 32   24    9      7     26.916667  78.747137
# 33   17    9     16     27.142045  79.001807
# 34   10    9     13     27.333333  76.459191
# 35    3    9     14           NaN        NaN
# 36   27    8     11           NaN        NaN

# %%
sns.countplot(x="Casos", data=df1);

# %%
columns_to_remove = ["SE","id","casos_est",
                     "casos_est_min","casos_est_max",
                     "p_rt1","p_inc100k",
                     "Localidade_id","nivel",
                     "casprov","casprov_est","casprov_est_min",
                     "casprov_est_max","casconf","tweet","Rt","pop","receptivo",
                     "transmissao","nivel_inc","notif_accum_year","versao_modelo" ]
df = df.drop(columns_to_remove, axis=1)
df.sample(4)
# Out:
#    data_iniSE  casos    tempmin    umidmax    umidmed    umidmin    tempmed  \
# 32 2023-09-24      7  26.277778  82.962577  78.747137  72.475238  26.916667
# 21 2023-12-10      6  27.064516  83.964228  76.038369  67.626502  27.919355
# 18 2023-12-31      6  27.850000  82.310735  80.986075  79.661418  27.950000
# 12 2024-02-11     75  27.666667  85.566030  84.707208  83.928550  27.841270
#
#       tempmax
# 32  27.944444
# 21  29.516129
# 18  28.050000
# 12  28.000000

# %%
df.isnull().sum()
# Out:
# data_iniSE    0
# casos         0
# tempmin       4
# umidmax       0
# umidmed       4
# umidmin       4
# tempmed       4
# tempmax       4
# dtype: int64

# %%
df1_treino = df1.dropna(subset=["TemperaturaM","UmidadeM"])

# %%
X = df1_treino.drop('Casos',axis=1)
y= df1_treino['Casos']

# %%
X
# Out:
#     Dia  Mês  TemperaturaM   UmidadeM
# 0     5    5     28.488889  80.711254
# 1    28    4     27.304545  87.276541
# 2    21    4     27.113636  85.237595
# 3    14    4     27.684211  86.518861
# 4     7    4     27.736842  87.234853
# 5    31    3     28.125000  84.341718
# 6    24    3     27.361111  88.569791
# 7    17    3     28.175000  84.939883
# 8    10    3     27.900000  86.565718
# 9     3    3     28.156863  81.933883
# 10   25    2     27.075000  86.717874
# 11   18    2     27.681818  85.085193
# 12   11    2     27.841270  84.707208
# 13    4    2     29.000000  78.714073
# 14   28    1     28.928571  75.526337
# 15   21    1     28.714286  77.418077
# 16   14    1     28.000000  78.470939
# 17    7    1     28.214286  77.653739
# 18   31   12     27.950000  80.986075
# 19   24   12     28.101449  79.934828
# 20   17   12     27.978261  79.063176
# 21   10   12     27.919355  76.038369
# 22    3   12     28.402777  73.772622
# 25   12   11     27.230769  79.022647
# 26    5   11     27.800000  73.516632
# 27   29   10     27.507246  77.109717
# 28   22   10     27.015873  77.925172
# 29   15   10     27.119318  76.632077
# 30    8   10     27.193750  78.153370
# 31    1   10     27.125000  76.299059
# 32   24    9     26.916667  78.747137
# 33   17    9     27.142045  79.001807
# 34   10    9     27.333333  76.459191

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.3,random_state= 42)

# %%
sca = preprocessing.StandardScaler()

# %%
cols = X.columns
cols
# Out:
# Index(['Dia', 'Mês', 'TemperaturaM', 'UmidadeM'], dtype='object')

# %%
df["data_iniSE"].dtype
#float_cols = X_train
# Out:
# dtype('<M8[ns]')

# %%
float_cols = X_train

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
df.data_iniSE = df['data_iniSE']

# %%
df.dtypes
# Out:
# data_iniSE    datetime64[ns]
# casos                  int64
# tempmin              float64
# umidmax              float64
# umidmed              float64
# umidmin              float64
# tempmed              float64
# tempmax              float64
# dtype: object

# %%
X_train
df1.drop([12,16,23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      3     27.304545  87.276541
# 2    21    4     16     27.113636  85.237595
# 3    14    4     36     27.684211  86.518861
# 4     7    4     59     27.736842  87.234853
# 5    31    3     28     28.125000  84.341718
# 6    24    3     18     27.361111  88.569791
# 7    17    3     29     28.175000  84.939883
# 8    10    3     26     27.900000  86.565718
# 9     3    3     41     28.156863  81.933883
# 10   25    2     73     27.075000  86.717874
# 11   18    2     86     27.681818  85.085193
# 13    4    2     26     29.000000  78.714073
# 14   28    1     32     28.928571  75.526337
# 15   21    1     11     28.714286  77.418077
# 17    7    1     12     28.214286  77.653739
# 18   31   12      6     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      1     27.978261  79.063176
# 21   10   12      6     27.919355  76.038369
# 22    3   12      3     28.402777  73.772622
# 25   12   11     10     27.230769  79.022647
# 26    5   11     24     27.800000  73.516632
# 27   29   10     11     27.507246  77.109717
# 28   22   10     14     27.015873  77.925172
# 29   15   10     13     27.119318  76.632077
# 30    8   10     12     27.193750  78.153370
# 31    1   10     14     27.125000  76.299059
# 32   24    9      7     26.916667  78.747137
# 33   17    9     16     27.142045  79.001807
# 34   10    9     13     27.333333  76.459191

# %%
y_train
df1.drop([23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      3     27.304545  87.276541
# 2    21    4     16     27.113636  85.237595
# 3    14    4     36     27.684211  86.518861
# 4     7    4     59     27.736842  87.234853
# 5    31    3     28     28.125000  84.341718
# 6    24    3     18     27.361111  88.569791
# 7    17    3     29     28.175000  84.939883
# 8    10    3     26     27.900000  86.565718
# 9     3    3     41     28.156863  81.933883
# 10   25    2     73     27.075000  86.717874
# 11   18    2     86     27.681818  85.085193
# 12   11    2     75     27.841270  84.707208
# 13    4    2     26     29.000000  78.714073
# 14   28    1     32     28.928571  75.526337
# 15   21    1     11     28.714286  77.418077
# 16   14    1      4     28.000000  78.470939
# 17    7    1     12     28.214286  77.653739
# 18   31   12      6     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      1     27.978261  79.063176
# 21   10   12      6     27.919355  76.038369
# 22    3   12      3     28.402777  73.772622
# 25   12   11     10     27.230769  79.022647
# 26    5   11     24     27.800000  73.516632
# 27   29   10     11     27.507246  77.109717
# 28   22   10     14     27.015873  77.925172
# 29   15   10     13     27.119318  76.632077
# 30    8   10     12     27.193750  78.153370
# 31    1   10     14     27.125000  76.299059
# 32   24    9      7     26.916667  78.747137
# 33   17    9     16     27.142045  79.001807
# 34   10    9     13     27.333333  76.459191

# %%
df
df1.drop([12,16,23,24,35,36])
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      3     27.304545  87.276541
# 2    21    4     16     27.113636  85.237595
# 3    14    4     36     27.684211  86.518861
# 4     7    4     59     27.736842  87.234853
# 5    31    3     28     28.125000  84.341718
# 6    24    3     18     27.361111  88.569791
# 7    17    3     29     28.175000  84.939883
# 8    10    3     26     27.900000  86.565718
# 9     3    3     41     28.156863  81.933883
# 10   25    2     73     27.075000  86.717874
# 11   18    2     86     27.681818  85.085193
# 13    4    2     26     29.000000  78.714073
# 14   28    1     32     28.928571  75.526337
# 15   21    1     11     28.714286  77.418077
# 17    7    1     12     28.214286  77.653739
# 18   31   12      6     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      1     27.978261  79.063176
# 21   10   12      6     27.919355  76.038369
# 22    3   12      3     28.402777  73.772622
# 25   12   11     10     27.230769  79.022647
# 26    5   11     24     27.800000  73.516632
# 27   29   10     11     27.507246  77.109717
# 28   22   10     14     27.015873  77.925172
# 29   15   10     13     27.119318  76.632077
# 30    8   10     12     27.193750  78.153370
# 31    1   10     14     27.125000  76.299059
# 32   24    9      7     26.916667  78.747137
# 33   17    9     16     27.142045  79.001807
# 34   10    9     13     27.333333  76.459191

# %%
X_train = sca.fit_transform(X_train)
X_train = pd.DataFrame(X_train,columns=cols)
X_test = sca.transform(X_test)
X_test = pd.DataFrame(X_test,columns=cols)

# %%
knn_model = KNeighborsRegressor(n_neighbors=3)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
X_train
# Out:
#          Dia       Mês  TemperaturaM  UmidadeM
# 0  -1.049616 -0.613151      0.093143  1.370976
# 1  -0.298557 -1.355387      0.561182 -0.496159
# 2   1.525441 -0.860563      0.783501  0.754599
# 3  -1.371498 -1.107975      2.339732 -0.444360
# 4   0.130619 -1.107975     -0.004720  0.912995
# 5  -1.264204  1.118732      0.205472 -1.551665
# 6   1.203559 -0.613151     -0.675718  1.379858
# 7   0.452501 -0.613151     -1.015260  0.945464
# 8  -1.693380  0.871320     -0.995049 -0.958874
# 9  -0.298557 -0.613151     -0.000465  1.218435
# 10 -0.191263  0.871320     -1.005154 -0.887925
# 11 -0.513145  1.118732     -0.806933 -0.378619
# 12  0.774383  0.623908     -1.365580 -0.437315
# 13 -1.478792  1.366144      1.277542 -1.497126
# 14  1.525441  1.366144      0.472255  0.039686
# 15  1.310853  0.871320     -0.315205 -0.786165
# 16  0.774383 -0.860563     -0.575114  1.655382
# 17  0.023325  1.366144      0.522518 -0.369984
# 18 -0.727734  0.623908     -0.624518 -0.924758
# 19  0.023325 -0.860563      0.872429  0.882037
# 20  0.881677 -1.107975     -1.083977  1.260835
# 21  1.203559 -1.355387      2.212693 -1.123501
# 22 -0.942322  0.871320     -0.872774 -0.563817

# %%
y_pred = knn_model.predict(X_test)
y_pred
# Out:
# array([10.        , 20.66666667, 10.33333333, 19.66666667, 41.33333333,
#        30.66666667,  6.        ,  9.33333333, 60.33333333, 19.66666667])

# %%
y_train
# Out:
# 4     59
# 16     4
# 5     28
# 13    26
# 11    86
# 26    24
# 1      3
# 2     16
# 31    14
# 3     36
# 29    13
# 25    10
# 32     7
# 22     3
# 18     6
# 27    11
# 6     18
# 20     1
# 34    13
# 7     29
# 10    73
# 14    32
# 30    12
# Name: Casos, dtype: int64

# %%
#Dados nulos
df1.isnull().sum()
# Out:
# Dia             0
# Mês             0
# Casos           0
# TemperaturaM    4
# UmidadeM        4
# dtype: int64

# %%
sns.countplot(x="Casos", data=df1);

# %%
fig = px.scatter(df1, x="Casos",
                 y="Mês",
                 title= "Numeros de Casos")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="21de9c00-7f9a-4804-9c46-eb694a7cbd34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21de9c00-7f9a-4804-9c46-eb694a7cbd34")) {                    Plotly.newPlot(                        "21de9c00-7f9a-4804-9c46-eb694a7cbd34",                        [{"hovertemplate":"Casos=%{x}\u003cbr\u003eM\u00eas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0,3,16,36,59,28,18,29,26,41,73,86,75,26,32,11,4,12,6,1,1,6,3,2,8,10,24,11,14,13,12,14,7,16,13,14,11],"xaxis":"x","y":[5,4,4,4,4,3,3,3,3,3,2,2,2,2,1,1,1,1,12,12,12,12,12,11,11,11,11,10,10,10,10,10,9,9,9,9,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"typ ...

# %%
fig = px.scatter(x=y_test, y=y_pred, title="Casos por Mês", trendline="ols", labels= {"X":"Casos","y":"Mês"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="88758d46-ed5d-41d5-a99e-f59f301799b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88758d46-ed5d-41d5-a99e-f59f301799b1")) {                    Plotly.newPlot(                        "88758d46-ed5d-41d5-a99e-f59f301799b1",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eM\u00eas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[16,11,14,12,26,41,1,6,75,0],"xaxis":"x","y":[10.0,20.666666666666668,10.333333333333334,19.666666666666668,41.333333333333336,30.666666666666668,6.0,9.333333333333334,60.333333333333336,19.666666666666668],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ey = 0.66187 * x + 9.43023\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.778086\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003eM\u00eas=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0,1,6,11,12,14,16,26,41,75],"xaxis":"x","y":[9.430234556233355,10.092104132657447,13.401452014777904,16.71079989689836,17.372669473322453,18.696408626170637,20.02014777901882,26.638843543259735,36.566887189621106,59.070452788040214],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"# ...

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(12,8))

# %%
sns.countplot(x="Casos", data=df1)
plt.title("Nível de casos")
# Out:
# Text(0.5, 1.0, 'Nível de casos')

# %%
decision_tree = DecisionTreeClassifier()

# %%
df1
# Out:
#     Dia  Mês  Casos  TemperaturaM   UmidadeM
# 0     5    5      0     28.488889  80.711254
# 1    28    4      3     27.304545  87.276541
# 2    21    4     16     27.113636  85.237595
# 3    14    4     36     27.684211  86.518861
# 4     7    4     59     27.736842  87.234853
# 5    31    3     28     28.125000  84.341718
# 6    24    3     18     27.361111  88.569791
# 7    17    3     29     28.175000  84.939883
# 8    10    3     26     27.900000  86.565718
# 9     3    3     41     28.156863  81.933883
# 10   25    2     73     27.075000  86.717874
# 11   18    2     86     27.681818  85.085193
# 12   11    2     75     27.841270  84.707208
# 13    4    2     26     29.000000  78.714073
# 14   28    1     32     28.928571  75.526337
# 15   21    1     11     28.714286  77.418077
# 16   14    1      4     28.000000  78.470939
# 17    7    1     12     28.214286  77.653739
# 18   31   12      6     27.950000  80.986075
# 19   24   12      1     28.101449  79.934828
# 20   17   12      1     27.978261  79.063176
# 21   10   12      6     27.919355  76.038369
# 22    3   12      3     28.402777  73.772622
# 23   26   11      2           NaN        NaN
# 24   19   11      8           NaN        NaN
# 25   12   11     10     27.230769  79.022647
# 26    5   11     24     27.800000  73.516632
# 27   29   10     11     27.507246  77.109717
# 28   22   10     14     27.015873  77.925172
# 29   15   10     13     27.119318  76.632077
# 30    8   10     12     27.193750  78.153370
# 31    1   10     14     27.125000  76.299059
# 32   24    9      7     26.916667  78.747137
# 33   17    9     16     27.142045  79.001807
# 34   10    9     13     27.333333  76.459191
# 35    3    9     14           NaN        NaN
# 36   27    8     11           NaN        NaN

# %%
X_test
# Out:
#         Dia       Mês  TemperaturaM  UmidadeM
# 0  0.023325  0.623908     -0.964733 -0.383059
# 1  0.452501 -1.355387      1.831575 -0.720469
# 2  0.559795  0.871320     -1.189137 -0.612434
# 3 -1.049616 -1.355387      0.942300 -0.670262
# 4 -0.727734 -0.860563      0.383327  1.228418
# 5 -1.478792 -0.860563      0.840170  0.241615
# 6  0.774383  1.366144      0.741615 -0.184280
# 7 -0.727734  1.366144      0.417750 -1.014413
# 8 -0.620439 -1.107975      0.278873  0.832466
# 9 -1.264204 -0.365739      1.430696 -0.018864

# %%
def evaluate_regression_model(model,X_test,y_test):
    pred = model.predict(X_test)
    print("R Square Error : ",r2_score(y_test,pred))
    print("Mean Absolute Error (MAE) : ",mean_absolute_error(y_test,pred))
    print("Root Mean Squared Error (RMSE) : ",np.sqrt(mean_absolute_error(y_test,pred)))

# %%
evaluate_regression_model(knn_model, X_test, y_test)
# Out:
# R Square Error :  0.7462076734350984
# Mean Absolute Error (MAE) :  9.533333333333333
# Root Mean Squared Error (RMSE) :  3.0876096471758427
